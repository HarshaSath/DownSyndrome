# %% [markdown]
# # Importing libraries

# %%
# import tensorflow as tf
import numpy as np
import pandas as pd
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, Dense, GlobalMaxPooling1D,Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the dataset

# %%
content = open('chatbt.json')
data1 = json.load(content)

# %% [markdown]
# # getting all the data to lists

# %%
tags = []
inputs = []
responses = {}
for intent in data1['intents']:
    responses[intent['tag']]=intent['responses']
    for lines in intent['input']:
        inputs.append(lines)
        tags.append(intent['tag'])

# %% [markdown]
# # converting to dataframe

# %%
data = pd.DataFrame({"input":inputs,"tag":tags})

# %% [markdown]
# # printing the data

# %%
data
# Out:
#                                                  input        tag
# 0                                                Hello   greeting
# 1                                                   hi   greeting
# 2                                             whats up   greeting
# 3                                   what is your name?  whatiName
# 4                                         who are you?  whatiName
# ..                                                 ...        ...
# 162  How have advances in medicine and therapy chan...
# 163  Can you explain how developments in medicine a...
# 164  I'd like to learn more about the ways in which...
# 165  Tell me about the changes in the lives of indi...
# 166  I'm interested in understanding how developmen...
#
# [167 rows x 2 columns]

# %% [markdown]
# # removing punctuations

# %%
import string
data['input'] = data['input'].apply(lambda wrd:[ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
data['input'] = data['input'].apply(lambda wrd: ''.join(wrd))
data
# Out:
#                                                  input        tag
# 0                                                hello   greeting
# 1                                                   hi   greeting
# 2                                             whats up   greeting
# 3                                    what is your name  whatiName
# 4                                          who are you  whatiName
# ..                                                 ...        ...
# 162  how have advances in medicine and therapy chan...
# 163  can you explain how developments in medicine a...
# 164  id like to learn more about the ways in which ...
# 165  tell me about the changes in the lives of indi...
# 166  im interested in understanding how development...
#
# [167 rows x 2 columns]

# %% [markdown]
# # tokenize the data

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(data['input'])
train = tokenizer.texts_to_sequences(data['input'])
#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['tag'])

# %%
input_shape = x_train.shape[1]
print(input_shape)
# Out:
# 26

# %% [markdown]
# # define vocabulary

# %%
vocabulary = len(tokenizer.word_index)
print("number of unique words : ",vocabulary)
output_length = le.classes_.shape[0]
print("output length: ",output_length)
# Out:
# number of unique words :  422
# output length:  32

# %%
def get_model():
    #creating the model
    i = Input(shape=(input_shape,))
    x = Embedding(vocabulary+1,10)(i)
    x = LSTM(10,return_sequences=True)(x)
    x = Flatten()(x)
    x = Dense(output_length,activation="softmax")(x)
    model = Model(i,x)
    return model

# %%
model = get_model()

# %% [markdown]
# # compiling the model

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # training the model

# %%
train = model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 7s 39ms/step - loss: 3.4675 - accuracy: 0.0240
# Epoch 2/200
# 6/6 [==============================] - 0s 32ms/step - loss: 3.4611 - accuracy: 0.0838
# Epoch 3/200
# 6/6 [==============================] - 0s 31ms/step - loss: 3.4557 - accuracy: 0.0898
# Epoch 4/200
# 6/6 [==============================] - 0s 33ms/step - loss: 3.4503 - accuracy: 0.0898
# Epoch 5/200
# 6/6 [==============================] - 0s 31ms/step - loss: 3.4439 - accuracy: 0.0898
# Epoch 6/200
# 6/6 [==============================] - 0s 29ms/step - loss: 3.4366 - accuracy: 0.0898
# Epoch 7/200
# 6/6 [==============================] - 0s 30ms/step - loss: 3.4274 - accuracy: 0.0898
# Epoch 8/200
# 6/6 [==============================] - 0s 31ms/step - loss: 3.4157 - accuracy: 0.0898
# Epoch 9/200
# 6/6 [==============================] - 0s 32ms/step - loss: 3.4005 - accuracy: 0.0898
# Epoch 10/200
# 6/6 [==============================] - 0s 29ms/step - loss: 3.3807 - accuracy: 0.0898
# Epoch 11/200
# 6/6 [==============================] - 0s 30ms/step - loss: 3.3577 - accuracy: 0.0898
# Epoch 12/200
# 6/6 [==============================] - 0s 30ms/step - loss: 3.3254 - accuracy: 0.0898
# Epoch 13/200
# 6/6 [==============================] - 0s 29ms/step - loss: 3.2851 - accuracy: 0.0898
# Epoch 14/200
# 6/6 [==============================] - 0s 31ms/step - loss: 3.2367 - accuracy: 0.0898
# Epoch 15/200
# 6/6 [==============================] - 0s 30ms/step - loss: 3.1809 - accuracy: 0.0898
# Epoch 16/200
# 6/6 [==============================] - 0s 29ms/step - loss: 3.1128 - accuracy: 0.0898
# Epoch 17/200
# 6/6 [==============================] - 0s 30ms/step - loss: 3.0467 - accuracy: 0.1198
# Epoch 18/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.9751 - accuracy: 0.1377
# Epoch 19/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.9035 - accuracy: 0.1377
# Epoch 20/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.8333 - accuracy: 0.1617
# Epoch 21/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.7626 - accuracy: 0.2096
# Epoch 22/200
# 6/6 [==============================] - 0s 28ms/step - loss: 2.6820 - accuracy: 0.2575
# Epoch 23/200
# 6/6 [==============================] - 0s 29ms/step - loss: 2.6030 - accuracy: 0.2455
# Epoch 24/200
# 6/6 [==============================] - 0s 29ms/step - loss: 2.5176 - accuracy: 0.2754
# Epoch 25/200
# 6/6 [==============================] - 0s 32ms/step - loss: 2.4381 - accuracy: 0.2874
# Epoch 26/200
# 6/6 [==============================] - 0s 28ms/step - loss: 2.3573 - accuracy: 0.3353
# Epoch 27/200
# 6/6 [==============================] - 0s 28ms/step - loss: 2.2756 - accuracy: 0.3832
# Epoch 28/200
# 6/6 [==============================] - 0s 29ms/step - loss: 2.2020 - accuracy: 0.4072
# Epoch 29/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1336 - accuracy: 0.4192
# Epoch 30/200
# 6/6 [==============================] - 0s 29ms/step - loss: 2.0704 - accuracy: 0.4311
# Epoch 31/200
# 6/6 [==============================] - 0s 30ms/step - loss: 2.0053 - accuracy: 0.4970
# Epoch 32/200
# 6/6 [==============================] - 0s 30ms/step - loss: 1.9351 - accuracy: 0.4970
# Epoch 33/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.8733 - accuracy: 0.5449
# Epoch 34/200
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8154 - accuracy: 0.5389
# Epoch 35/200
# 6/6 [==============================] - 0s 29ms/step - loss: 1.7584 - accuracy: 0.5689
# Epoch 36/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.7069 - accuracy: 0.6228
# Epoch 37/200
# 6/6 [==============================] - 0s 25ms/step - loss: 1.6527 - accuracy: 0.6467
# Epoch 38/200
# 6/6 [==============================] - 0s 44ms/step - loss: 1.6057 - accuracy: 0.6647
# Epoch 39/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5565 - accuracy: 0.6467
# Epoch 40/200
# 6/6 [==============================] - 0s 35ms/step - loss: 1.5036 - accuracy: 0.6467
# Epoch 41/200
# 6/6 [==============================] - 0s 20ms/step - loss: 1.4599 - accuracy: 0.6707
# Epoch 42/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.4140 - accuracy: 0.6946
# Epoch 43/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.3735 - accuracy: 0.6707
# Epoch 44/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.3302 - accuracy: 0.7246
# Epoch 45/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.2891 - accuracy: 0.7605
# Epoch 46/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.2539 - accuracy: 0.7305
# Epoch 47/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.2179 - accuracy: 0.7545
# Epoch 48/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1750 - accuracy: 0.7545
# Epoch 49/200
# 6/6 [==============================] - 0s 21ms/step - loss: 1.1366 - accuracy: 0.7665
# Epoch 50/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.0937 - accuracy: 0.7844
# Epoch 51/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.0644 - accuracy: 0.7844
# Epoch 52/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.0431 - accuracy: 0.8263
# Epoch 53/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.9978 - accuracy: 0.8263
# Epoch 54/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.9647 - accuracy: 0.8263
# Epoch 55/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.9324 - accuracy: 0.8683
# Epoch 56/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.9019 - accuracy: 0.8503
# Epoch 57/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8783 - accuracy: 0.8623
# Epoch 58/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8521 - accuracy: 0.8683
# Epoch 59/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8283 - accuracy: 0.8802
# Epoch 60/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7950 - accuracy: 0.8802
# Epoch 61/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.7652 - accuracy: 0.8982
# Epoch 62/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7681 - accuracy: 0.8743
# Epoch 63/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7583 - accuracy: 0.8922
# Epoch 64/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7272 - accuracy: 0.8802
# Epoch 65/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6978 - accuracy: 0.9042
# Epoch 66/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6588 - accuracy: 0.9042
# Epoch 67/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6506 - accuracy: 0.9042
# Epoch 68/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6343 - accuracy: 0.9042
# Epoch 69/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6047 - accuracy: 0.9222
# Epoch 70/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5849 - accuracy: 0.9281
# Epoch 71/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5799 - accuracy: 0.9341
# Epoch 72/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5623 - accuracy: 0.9281
# Epoch 73/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5407 - accuracy: 0.9401
# Epoch 74/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5234 - accuracy: 0.9401
# Epoch 75/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5049 - accuracy: 0.9461
# Epoch 76/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4929 - accuracy: 0.9521
# Epoch 77/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4771 - accuracy: 0.9521
# Epoch 78/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4625 - accuracy: 0.9581
# Epoch 79/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4529 - accuracy: 0.9461
# Epoch 80/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4358 - accuracy: 0.9581
# Epoch 81/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4220 - accuracy: 0.9641
# Epoch 82/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4086 - accuracy: 0.9641
# Epoch 83/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3979 - accuracy: 0.9641
# Epoch 84/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3894 - accuracy: 0.9641
# Epoch 85/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3796 - accuracy: 0.9581
# Epoch 86/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3702 - accuracy: 0.9581
# Epoch 87/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3575 - accuracy: 0.9641
# Epoch 88/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3509 - accuracy: 0.9581
# Epoch 89/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3409 - accuracy: 0.9701
# Epoch 90/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3330 - accuracy: 0.9760
# Epoch 91/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3234 - accuracy: 0.9760
# Epoch 92/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3151 - accuracy: 0.9760
# Epoch 93/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3073 - accuracy: 0.9760
# Epoch 94/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2987 - accuracy: 0.9820
# Epoch 95/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2927 - accuracy: 0.9820
# Epoch 96/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2816 - accuracy: 0.9820
# Epoch 97/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2741 - accuracy: 0.9760
# Epoch 98/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2673 - accuracy: 0.9760
# Epoch 99/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2618 - accuracy: 0.9820
# Epoch 100/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2560 - accuracy: 0.9820
# Epoch 101/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2492 - accuracy: 0.9820
# Epoch 102/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2422 - accuracy: 0.9760
# Epoch 103/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2424 - accuracy: 0.9820
# Epoch 104/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2345 - accuracy: 0.9820
# Epoch 105/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2264 - accuracy: 0.9820
# Epoch 106/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2191 - accuracy: 0.9820
# Epoch 107/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2178 - accuracy: 0.9760
# Epoch 108/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2119 - accuracy: 0.9820
# Epoch 109/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2058 - accuracy: 0.9880
# Epoch 110/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2011 - accuracy: 0.9880
# Epoch 111/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1982 - accuracy: 0.9820
# Epoch 112/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1918 - accuracy: 0.9880
# Epoch 113/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1871 - accuracy: 0.9880
# Epoch 114/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1834 - accuracy: 0.9880
# Epoch 115/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1817 - accuracy: 0.9820
# Epoch 116/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1763 - accuracy: 0.9880
# Epoch 117/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1730 - accuracy: 0.9880
# Epoch 118/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1697 - accuracy: 0.9820
# Epoch 119/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1661 - accuracy: 0.9760
# Epoch 120/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1671 - accuracy: 0.9940
# Epoch 121/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1632 - accuracy: 0.9820
# Epoch 122/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1617 - accuracy: 0.9880
# Epoch 123/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1536 - accuracy: 0.9820
# Epoch 124/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1496 - accuracy: 0.9940
# Epoch 125/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1473 - accuracy: 0.9940
# Epoch 126/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1448 - accuracy: 0.9880
# Epoch 127/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1407 - accuracy: 0.9880
# Epoch 128/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1385 - accuracy: 0.9940
# Epoch 129/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1351 - accuracy: 0.9940
# Epoch 130/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1329 - accuracy: 0.9940
# Epoch 131/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1314 - accuracy: 0.9940
# Epoch 132/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1302 - accuracy: 0.9880
# Epoch 133/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1262 - accuracy: 0.9940
# Epoch 134/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1256 - accuracy: 0.9880
# Epoch 135/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1253 - accuracy: 0.9940
# Epoch 136/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1212 - accuracy: 0.9940
# Epoch 137/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1180 - accuracy: 0.9940
# Epoch 138/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1169 - accuracy: 0.9940
# Epoch 139/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1161 - accuracy: 0.9940
# Epoch 140/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1140 - accuracy: 0.9940
# Epoch 141/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1104 - accuracy: 0.9940
# Epoch 142/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1099 - accuracy: 0.9880
# Epoch 143/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1080 - accuracy: 0.9940
# Epoch 144/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1049 - accuracy: 0.9940
# Epoch 145/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1038 - accuracy: 0.9940
# Epoch 146/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1017 - accuracy: 0.9940
# Epoch 147/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1017 - accuracy: 0.9940
# Epoch 148/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1006 - accuracy: 0.9940
# Epoch 149/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0960 - accuracy: 0.9940
# Epoch 150/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0972 - accuracy: 0.9880
# Epoch 151/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0960 - accuracy: 0.9880
# Epoch 152/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0922 - accuracy: 0.9940
# Epoch 153/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0905 - accuracy: 0.9880
# Epoch 154/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0912 - accuracy: 0.9880
# Epoch 155/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0893 - accuracy: 0.9940
# Epoch 156/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0894 - accuracy: 0.9940
# Epoch 157/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0892 - accuracy: 0.9940
# Epoch 158/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0915 - accuracy: 0.9940
# Epoch 159/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0861 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0940 - accuracy: 0.9940
# Epoch 161/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0916 - accuracy: 0.9940
# Epoch 162/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0860 - accuracy: 0.9940
# Epoch 163/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0804 - accuracy: 0.9940
# Epoch 164/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0779 - accuracy: 0.9940
# Epoch 165/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0774 - accuracy: 0.9940
# Epoch 166/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0761 - accuracy: 0.9940
# Epoch 167/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0748 - accuracy: 0.9940
# Epoch 168/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0733 - accuracy: 0.9940
# Epoch 169/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0730 - accuracy: 0.9940
# Epoch 170/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0712 - accuracy: 0.9940
# Epoch 171/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0716 - accuracy: 0.9940
# Epoch 172/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0693 - accuracy: 0.9940
# Epoch 173/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0693 - accuracy: 0.9880
# Epoch 174/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0681 - accuracy: 0.9940
# Epoch 175/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0694 - accuracy: 0.9940
# Epoch 176/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0701 - accuracy: 0.9940
# Epoch 177/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0680 - accuracy: 0.9940
# Epoch 178/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0651 - accuracy: 0.9940
# Epoch 179/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0644 - accuracy: 0.9940
# Epoch 180/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0634 - accuracy: 0.9940
# Epoch 181/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0633 - accuracy: 0.9940
# Epoch 182/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0618 - accuracy: 0.9940
# Epoch 183/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0611 - accuracy: 0.9940
# Epoch 184/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0627 - accuracy: 0.9880
# Epoch 185/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0615 - accuracy: 0.9880
# Epoch 186/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0591 - accuracy: 0.9940
# Epoch 187/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0600 - accuracy: 0.9940
# Epoch 188/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0612 - accuracy: 0.9940
# Epoch 189/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0609 - accuracy: 0.9940
# Epoch 190/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0581 - accuracy: 0.9940
# Epoch 191/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0576 - accuracy: 0.9940
# Epoch 192/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0553 - accuracy: 0.9940
# Epoch 193/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0553 - accuracy: 0.9940
# Epoch 194/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0539 - accuracy: 0.9940
# Epoch 195/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0541 - accuracy: 0.9940
# Epoch 196/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0560 - accuracy: 0.9940
# Epoch 197/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0549 - accuracy: 0.9940
# Epoch 198/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0524 - accuracy: 0.9940
# Epoch 199/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0509 - accuracy: 0.9940
# Epoch 200/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0502 - accuracy: 0.9940

# %% [markdown]
# # plotting model accuracy

# %%
plt.plot(train.history['accuracy'],label='training set accuracy')
plt.plot(train.history['loss'],label='training set loss')
plt.legend()

# %% [markdown]
# # Saving model

# %%
model.save("downcyndrome_chatbot.h5")

# %% [markdown]
# # Testing Model

# %%
# Testing Model
# chatting
import random
from tensorflow import keras


#Loading model
reconstructed_model = keras.models.load_model("downcyndrome_chatbot.h5")


while True:
    texts_p = []
    prediction_input = input('You : ')
    
    #removing punctuation and converting to lowercase
    prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
    prediction_input = ''.join(prediction_input)
    texts_p.append(prediction_input)
    
    #tokenizing and padding
    prediction_input = tokenizer.texts_to_sequences(texts_p)
    prediction_input = np.array(prediction_input).reshape(-1)
    prediction_input = pad_sequences([prediction_input],input_shape)
    
    #getting output from model
    output = reconstructed_model.predict(prediction_input)
    output = output.argmax()
    
    #finding the right tag and predicting
    response_tag = le.inverse_transform([output])[0]
    print("ChatBot :",random.choice(responses[response_tag]))
    if response_tag == "goodbye":
        break
# Out:
# You : hi
# 1/1 [==============================] - 1s 1s/step
# ChatBot : Hi, How can i help you?
# You : I was watching a health documentary, and they mentioned kids with an unusually small head. It struck me because my child has the same. Can you advise?
# 1/1 [==============================] - 0s 62ms/step
# ChatBot : 1. Trisomy 21 (Nondisjunction) : This is the most common form, accounting for about 95% of all cases of Down syndrome. In trisomy 21, there is an extra chromosome 21 in every cell. This occurs when the chromosome pairs fail to separate properly during the formation of an egg or sperm, leading to an egg or sperm cell with an extra chromosome. When this cell is fertilized, the resulting individual has three copies of chromosome 21 in each cell instead of the usual two. , 2.Translocation Down Syndrome:This accounts for about 3-4% of cases. In translocation, part of chromosome 21 breaks off and attaches to another chromosome, typically chromosome 14. The total number of chromosomes in the cells remains 46, but the presence of extra genetic material from chromosome 21 causes Down syndrome characteristics. This type can be inherited. If one of the parents carries a translocation of chromosome 21 but does not have Down syndrome, they can pass the translocation to their child, resulting in Down syndrome for the child. 3.Mosaic Down Syndrome: This is the rarest type, accounting for about 1-2% of cases. In mosaicism, not all cells have an extra chromosome 21. Some cells have the typical two copies, while others have three. This happens due to an error in cell division after fertilization. The characteristics of Down syndrome in individuals with mosaicism can vary widely, depending on how many cells have the extra chromosome.
# You : thanks
# 1/1 [==============================] - 0s 46ms/step
# ChatBot : Hi, How can i help you?
# You : bye
# 1/1 [==============================] - 0s 48ms/step
# ChatBot : Hi, How can i help you?
